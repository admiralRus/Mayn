# %% [markdown]
# <a href="https://colab.research.google.com/github/admiralRus/Mayn/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Аттестационная работа номер 3

# %% [markdown]
# Подгружаем библиотеки

# %%
import dask.dataframe as dd # для временного хранения данных на диске
import pandas as pd #вызываем библиотеку пандас

# %% [markdown]
# Загружаем первый датасет Population.csv

# %%
url1="http://intersyn.net/Population.csv"

# %%
ddf1=dd.read_csv(url1) #присваиваем переменой загруженный датасет

# %%
ddf1 #видим, что на экран ничего не выводится без .compute()
# Out:
# Dask DataFrame Structure:
#               SortOrder  LocID    Notes ISO3_code ISO2_code SDMX_code LocTypeID LocTypeName ParentID Location  VarID Variant   Time MidPeriod AgeGrp AgeGrpStart AgeGrpSpan  PopMale PopFemale PopTotal
# npartitions=3
#                   int64  int64  float64   float64   float64     int64     int64      object    int64   object  int64  object  int64     int64  int64       int64      int64  float64   float64  float64
#                     ...    ...      ...       ...       ...       ...       ...         ...      ...      ...    ...     ...    ...       ...    ...         ...        ...      ...       ...      ...
#                     ...    ...      ...       ...       ...       ...       ...         ...      ...      ...    ...     ...    ...       ...    ...         ...        ...      ...       ...      ...
# ...

# %% [markdown]
# Давайте проанализируем датасет. Для этого поймём, что в нём содержится

# %%
ddf1.columns #для удобства выводим названия столбцов
# Out:
# Index(['SortOrder', 'LocID', 'Notes', 'ISO3_code', 'ISO2_code', 'SDMX_code',
#        'LocTypeID', 'LocTypeName', 'ParentID', 'Location', 'VarID', 'Variant',
#        'Time', 'MidPeriod', 'AgeGrp', 'AgeGrpStart', 'AgeGrpSpan', 'PopMale',
#        'PopFemale', 'PopTotal'],
#       dtype='object')

# %% [markdown]
# Как видим - датасет содержит информаци

# %%
ddf1.groupby('Location').aggregate({"PopMale": max}).compute()
# Out:
#                                     PopMale
# Location
# World                             72381.304
# Sub-Saharan Africa                18913.116
# Northern Africa and Western Asia   6069.833
# Central and Southern Asia         21058.608
# Eastern and South-Eastern Asia    22710.730
# ...                                     ...
# Samoa                                 3.096
# Tokelau                               0.040
# Tonga                                 1.686
# Tuvalu                                0.154
# Wallis and Futuna Islands             0.225
#
# [283 rows x 1 columns]
