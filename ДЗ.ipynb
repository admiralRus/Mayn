# %% [markdown]
# <a href="https://colab.research.google.com/github/admiralRus/Mayn/blob/main/%D0%94%D0%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#импорт библиотек для визуализации
import pandas as pd
import matplotlib.pyplot as plt
#даёт большую гибкость, но требует больше кода
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("cardio_data_processed.csv")
#Присваеваем переменной таблицу данных
pd.options.display.max_columns = None
#предписываем показывать на экране все столбцы таблицы
data
#проверяем
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 68200  99993  19240       2     168    76.0    120     80            1     1
# 68201  99995  22601       1     158   126.0    140     90            2     2
# 68202  99996  19066       2     183   105.0    180     90            3     1
# 68203  99998  22431       1     163    72.0    135     80            1     2
# 68204  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
строим тепловую карту
