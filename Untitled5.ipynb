# %% [markdown]
# <a href="https://colab.research.google.com/github/admiralRus/Mayn/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})

# %%
df.drop(1, axis=0, inplace=True)

# %%
df
# Out:
#    x
# 0  1
# 1  3
# 2  2

# %%
del df['y'] # df.drop('x', axis=1)

# %%
df1=pd.DataFrame({'x':[1,3,2], 'y':[2,4,1]})

# %%
df2=pd.DataFrame({'x':[3,1,3], 'y':[3,4,5]})

# %%
print (df1>=df2)
# Out:
#        x      y
# 0  False  False
# 1   True   True
# 2  False  False

# %%
df2[(df2<2)&(df2>0)]
# Out:
#      x   y
# 0  NaN NaN
# 1  1.0 NaN
# 2  NaN NaN

# %%
df2[(df2<2)&(df2>0)]
# Out:
#      x   y
# 0  NaN NaN
# 1  1.0 NaN
# 2  NaN NaN

# %%
df2[(df2<1)&(df2>2)]
# Out:
#     x   y
# 0 NaN NaN
# 1 NaN NaN
# 2 NaN NaN
