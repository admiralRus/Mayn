# %% [markdown]
# <a href="https://colab.research.google.com/github/admiralRus/Mayn/blob/main/2Attest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#импорт библиотек для визуализации
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas.core.groupby import groupby

# %%
Data=pd.read_csv("nasdaq.csv")
#Присваеваем переменной таблицу данных
pd.options.display.max_columns = None
#предписываем показывать на экране все столбцы таблицы
Data
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $117.10
# 1        AA                    Alcoa Corporation Common Stock     $50.85
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...     $9.82
# 3      AACG   ATA Creativity Global American Depositary Shares   $1.0595
# 4      AACI            Armada Acquisition Corp. I Common Stock     $9.86
# ...     ...                                                ...       ...
# 8353    ZWS      Zurn Water Solutions Corporation Common Stock    $27.97
# 8354     ZY                         Zymergen Inc. Common Stock    $1.505
# 8355   ZYME                       Zymeworks Inc. Common Shares     $5.54
# 8356   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock    $1.035
# 8357   ZYXI                            Zynex Inc. Common Stock     $7.58
#
#       Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# ...

# %%
Data.info()
Data.describe()
#проверяем на наличие пропусков и соответствие данных типам
#видим, что пропусков много и не все данные соответствуют своим типам
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8358 entries, 0 to 8357
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      8358 non-null   object
#  1   Name        8358 non-null   object
#  2   Last Sale   8358 non-null   object
#  3   Net Change  8358 non-null   float64
#  4   % Change    8358 non-null   object
#  5   Market Cap  7898 non-null   float64
#  6   Country     7559 non-null   object
#  7   IPO Year    5115 non-null   float64
#  8   Volume      8358 non-null   int64
#  9   Sector      6957 non-null   object
#  10  Industry    6956 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 718.4+ KB
#         Net Change    Market Cap     IPO Year        Volume
# count  8358.000000  7.898000e+03  5115.000000  8.358000e+03
# mean     -1.786770  6.695045e+09  2014.455914  6.840041e+05
# std      77.872831  4.911454e+10     9.882244  3.183031e+06
# ...

# %%
#убираем мешающие символы в столбцах и меняем строковой тип на десятичный
Data['Last Sale']=Data['Last Sale'].replace('\$','',regex=True).astype(float)
Data['% Change']=Data['% Change'].replace('\%','',regex=True).astype(float)
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8358 entries, 0 to 8357
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      8358 non-null   object
#  1   Name        8358 non-null   object
#  2   Last Sale   8358 non-null   float64
#  3   Net Change  8358 non-null   float64
#  4   % Change    8358 non-null   float64
#  5   Market Cap  7898 non-null   float64
#  6   Country     7559 non-null   object
#  7   IPO Year    5115 non-null   float64
#  8   Volume      8358 non-null   int64
#  9   Sector      6957 non-null   object
#  10  Industry    6956 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 718.4+ KB
