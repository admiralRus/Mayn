# %% [markdown]
# <a href="https://colab.research.google.com/github/admiralRus/Mayn/blob/main/Grafiki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#импорт библиотек для визуализации
import pandas as pd
import matplotlib.pyplot as plt
#даёт большую гибкость, но требует больше кода
import seaborn as sns

# %%
#построение графика
#plt.plot(x,y)
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y)

# %%
x1=[1,2,3,4,5]
y1=[10,20,30,40,50]
plt.plot(x1,y1, color='red', linestyle = "--", linewidth=5)
