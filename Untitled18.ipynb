# %% [markdown]
# <a href="https://colab.research.google.com/github/admiralRus/Mayn/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Итоговая аттестационная работа
# Выбрать один из предложенных датафреймов: https://disk.yandex.ru/d/GVIse_deHSPTpw. 2.Провести предварительный анализ и предобработку.
# 3.Решить 3-4 аналитические задачи, примеры которых перечислены на слайдах.
# 4.Оформить отчет в виде презентации. Отчет должен включать результаты исследований в виде таблиц, графиков, и необходимых пояснений, выводов и рекомендаций.
# 5.Подготовить доклад. Выйти на защиту.

# %% [markdown]
# 1. Подгружаем библиотеки и загружаем датасет

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %%
dataWe = pd.read_csv("weatherHistory.csv")

# %%
dataWe
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
dataWe.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
dataWe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
dataWe.columns=dataWe.columns.str.replace(" ", "_")
dataWe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted_Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip_Type               95936 non-null  object
#  3   Temperature_(C)           96453 non-null  float64
#  4   Apparent_Temperature_(C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind_Speed_(km/h)         96453 non-null  float64
#  7   Wind_Bearing_(degrees)    96453 non-null  float64
#  8   Visibility_(km)           96453 non-null  float64
#  9   Loud_Cover                96453 non-null  float64
#  10  Pressure_(millibars)      96453 non-null  float64
#  11  Daily_Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
dataWe.Precip_Type.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-5923a83ba3a9> in <cell line: 1>()
# ----> 1 dataWe.Precip_Type.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Precip_Type'

# %%
dataWe.dropna(inplace=True)
dataWe
# Out:
#                       Formatted_Date        Summary Precip_Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature_(C)  Apparent_Temperature_(C)  Humidity  Wind_Speed_(km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
dataWe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95936 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted_Date            95936 non-null  object
#  1   Summary                   95936 non-null  object
#  2   Precip_Type               95936 non-null  object
#  3   Temperature_(C)           95936 non-null  float64
#  4   Apparent_Temperature_(C)  95936 non-null  float64
#  5   Humidity                  95936 non-null  float64
#  6   Wind_Speed_(km/h)         95936 non-null  float64
#  7   Wind_Bearing_(degrees)    95936 non-null  float64
#  8   Visibility_(km)           95936 non-null  float64
#  9   Pressure_(millibars)      95936 non-null  float64
#  10  Daily_Summary             95936 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 8.8+ MB

# %%
dataWe.describe ()
# Out:
#        Temperature_(C)  Apparent_Temperature_(C)      Humidity  \
# count     95936.000000              95936.000000  95936.000000
# mean         11.940976                 10.862531      0.734841
# std           9.570671                 10.717812      0.195724
# min         -21.822222                -27.716667      0.000000
# 25%           4.604167                  2.276389      0.600000
# 50%          12.033333                 12.033333      0.780000
# 75%          18.844444                 18.844444      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind_Speed_(km/h)  Wind_Bearing_(degrees)  Visibility_(km)  \
# count       95936.000000            95936.000000     95936.000000
# mean           10.804936              187.518773        10.362402
# std             6.920727              107.385351         4.173780
# min             0.000000                0.000000         0.000000
# ...

# %%
dataWe.Loud_Cover.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-17b25e678107> in <cell line: 1>()
# ----> 1 dataWe.Loud_Cover.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Loud_Cover'

# %%
dataWe.Loud_Cover.value_counts()
# Out:
# 0.0    95936
# Name: Loud_Cover, dtype: int64

# %%
dataWe.drop("Loud_Cover", axis= 1 , inplace= True)
dataWe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-2b5533529a33> in <cell line: 1>()
# ----> 1 dataWe.drop("Loud_Cover", axis= 1 , inplace= True)
#       2 dataWe
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
dataWe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95936 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted_Date            95936 non-null  object
#  1   Summary                   95936 non-null  object
#  2   Precip_Type               95936 non-null  object
#  3   Temperature_(C)           95936 non-null  float64
#  4   Apparent_Temperature_(C)  95936 non-null  float64
#  5   Humidity                  95936 non-null  float64
#  6   Wind_Speed_(km/h)         95936 non-null  float64
#  7   Wind_Bearing_(degrees)    95936 non-null  float64
#  8   Visibility_(km)           95936 non-null  float64
#  9   Pressure_(millibars)      95936 non-null  float64
#  10  Daily_Summary             95936 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 8.8+ MB

# %%
dataWe["Formatted_Date"] = dataWe["Formatted_Date"].str.split(" ").str[0]
dataWe
# Out:
#       Formatted_Date        Summary Precip_Type  Temperature_(C)  \
# 0         2006-04-01  Partly Cloudy        rain         9.472222
# 1         2006-04-01  Partly Cloudy        rain         9.355556
# 2         2006-04-01  Mostly Cloudy        rain         9.377778
# 3         2006-04-01  Partly Cloudy        rain         8.288889
# 4         2006-04-01  Mostly Cloudy        rain         8.755556
# ...              ...            ...         ...              ...
# 96448     2016-09-09  Partly Cloudy        rain        26.016667
# 96449     2016-09-09  Partly Cloudy        rain        24.583333
# 96450     2016-09-09  Partly Cloudy        rain        22.038889
# 96451     2016-09-09  Partly Cloudy        rain        21.522222
# 96452     2016-09-09  Partly Cloudy        rain        20.438889
#
#        Apparent_Temperature_(C)  Humidity  Wind_Speed_(km/h)  \
# 0                      7.388889      0.89            14.1197
# ...

# %%
dataWe["Formatted_Date"] = pd.to_datetime(dataWe["Formatted_Date"])
dataWe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95936 entries, 0 to 96452
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted_Date            95936 non-null  datetime64[ns]
#  1   Summary                   95936 non-null  object
#  2   Precip_Type               95936 non-null  object
#  3   Temperature_(C)           95936 non-null  float64
#  4   Apparent_Temperature_(C)  95936 non-null  float64
#  5   Humidity                  95936 non-null  float64
#  6   Wind_Speed_(km/h)         95936 non-null  float64
#  7   Wind_Bearing_(degrees)    95936 non-null  float64
#  8   Visibility_(km)           95936 non-null  float64
#  9   Pressure_(millibars)      95936 non-null  float64
#  10  Daily_Summary             95936 non-null  object
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 8.8+ MB

# %%
dataWe.set_index("Formatted_Date", inplace=True)
dataWe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 95936 entries, 2006-04-01 to 2016-09-09
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Summary                   95936 non-null  object
#  1   Precip_Type               95936 non-null  object
#  2   Temperature_(C)           95936 non-null  float64
#  3   Apparent_Temperature_(C)  95936 non-null  float64
#  4   Humidity                  95936 non-null  float64
#  5   Wind_Speed_(km/h)         95936 non-null  float64
#  6   Wind_Bearing_(degrees)    95936 non-null  float64
#  7   Visibility_(km)           95936 non-null  float64
#  8   Pressure_(millibars)      95936 non-null  float64
#  9   Daily_Summary             95936 non-null  object
# dtypes: float64(7), object(3)
# memory usage: 8.1+ MB

# %%
dataWe
# Out:
#                       Summary Precip_Type  Temperature_(C)  \
# Formatted_Date
# 2006-04-01      Partly Cloudy        rain         9.472222
# 2006-04-01      Partly Cloudy        rain         9.355556
# 2006-04-01      Mostly Cloudy        rain         9.377778
# 2006-04-01      Partly Cloudy        rain         8.288889
# 2006-04-01      Mostly Cloudy        rain         8.755556
# ...                       ...         ...              ...
# 2016-09-09      Partly Cloudy        rain        26.016667
# 2016-09-09      Partly Cloudy        rain        24.583333
# 2016-09-09      Partly Cloudy        rain        22.038889
# 2016-09-09      Partly Cloudy        rain        21.522222
# 2016-09-09      Partly Cloudy        rain        20.438889
#
#                 Apparent_Temperature_(C)  Humidity  Wind_Speed_(km/h)  \
# Formatted_Date
# 2006-04-01                      7.388889      0.89            14.1197
# 2006-04-01                      7.227778      0.86            14.2646
# ...

# %%
# найдем среднее значение влажности за день
data2 = dataWe.groupby(dataWe.index.date)["Humidity"].mean()
data2
# Out:
# 2006-01-01    0.818333
# 2006-01-02    0.844583
# 2006-01-03    0.898333
# 2006-01-04    0.905417
# 2006-01-05    0.948333
#                 ...
# 2016-12-27    0.890000
# 2016-12-28    0.890000
# 2016-12-29    0.889583
# 2016-12-30    0.889167
# 2016-12-31    0.888750
# Name: Humidity, Length: 4009, dtype: float64

# %%
data2.plot()
plt.legend(['Humidity'], title='Легенда', frameon=True)

# %%
# найдем среднее значение температуры за день
data_new = dataWe.groupby(dataWe.index.date)["Temperature_(C)"].mean()
data_new
# Out:
# 2006-01-01    3.873148
# 2006-01-02    5.418519
# 2006-01-03    2.319444
# 2006-01-04    2.274074
# 2006-01-05    2.698148
#                 ...
# 2016-12-27    0.280324
# 2016-12-28    0.224306
# 2016-12-29    0.169676
# 2016-12-30    0.119444
# 2016-12-31    0.072454
# Name: Temperature_(C), Length: 4009, dtype: float64

# %%
data_new.plot()
plt.legend(['Temperature, С'], title='Легенда', frameon=True)

# %%
data_Wind_Speed = dataWe.groupby('Formatted_Date')['Wind_Speed_(km/h)'].mean()

# %%
plt.figure(figsize=(15,5))
data_Wind_Speed.plot(color='blue')
plt.xlabel("Date")
plt.ylabel("Wind Speed (km/h)")
plt.legend(['Wind Speed (km/h)'], frameon=True)

# %%
data_new = dataWe.groupby(data.index.date)["Pressure_(millibars)"].mean()
data_new
# Out:
# 2006-01-01    1012.279167
# 2006-01-02    1010.131667
# 2006-01-03    1020.805000
# 2006-01-04     981.826667
# 2006-01-05     935.988333
#                  ...
# 2016-12-27    1020.304583
# 2016-12-28    1020.334583
# 2016-12-29    1020.365833
# 2016-12-30    1020.395000
# 2016-12-31    1020.423750
# Name: Pressure_(millibars), Length: 4009, dtype: float64

# %%
data_Pressure = dataWe.groupby('Formatted_Date')['Pressure_(millibars)'].mean()

# %%
plt.figure(figsize=(15,5))
data_Pressure.plot(color='orange')
plt.xlabel("Date")
plt.ylabel("Pressure (millibars)")
plt.legend(['Pressure (millibars)'], frameon=True)

# %%
data_new = dataWe['Precip_Type'].value_counts()
plt.pie(data_new, labels=data_new.index, autopct='%1.1f%%', wedgeprops=dict(width=0.6))
plt.rc('font', size=8)
plt.show()
